# %% [markdown]
# # 4.8 Grouping and Aggregating

# %% [markdown]
# ## Contents:
# ### Set import variable
# ### Import orders_products_w_busy_days_times.pkl
# ### Define aggregation for entire df and analysis
# ### Add new field: Max order
# ### Add new field: Create loyalty flag per max_order data
# ### Add new field: Average price of items purchased as avg_spend¶
# ### Add new field: Create spending_flag per avg_spend data
# ### Add new field: Median frequency of customers as frequency_median
# ### Add new field: Create a frequency flag per the frequency_median
# ### Export final df
# # -----------------------------------

# %% [markdown]
# ### Import libraries and set import path

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Set path for use in import
path = r'C:\Users\XLT2\CFProjects\2023-04-07 Instacart Basket Analysis\02 Data'

# %% [markdown]
# ### Import current data set

# %%
# Import orders_products_w_busy_days_times.pkl
df_ords_prods_merge = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_w_busy_days_times.pkl'))

# %%
# Check data import
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138    prior            28          6                 11
# 1   1977647      138    prior            30          6                 17
# 2    389851      709    prior             2          0                 21
# 3    652770      764    prior             1          3                 13
# 4   1813452      764    prior             3          4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# 0                     3.0                  5          0   both
# 1                    20.0                  1          1   both
# 2                     6.0                 20          0   both
# 3                     0.0                 10          0   both
# 4                     9.0                 11          1   both
#
#      price_range_loc     busiest_day       busiest_days_2  \
# 0  Mid-range product  Regularly busy  Regularly busy days
# 1  Mid-range product  Regularly busy  Regularly busy days
# 2  Mid-range product     Busiest day         Busiest days
# 3  Mid-range product  Regularly busy      Least busy days
# 4  Mid-range product      Least busy      Least busy days
#
#           busiest_hours
# 0         Busiest hours
# 1  Regularly busy hours
# 2  Regularly busy hours
# 3  Regularly busy hours
# 4  Regularly busy hours

# %%
# Confirm rows
df_ords_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
# ### Step 2 - Define aggregation for entire df

# %%
# Groupby dept_id - aggregate order number by mean
df_ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Step 3 - Analysis of aggregation results
# The results are different, but similar. Since we arbitrarily sliced the first 1M records, we will lose records, but the trend holds relatively true. If we ran the sliced data repeatedly and added a larger slice of the data on each run, we would slowly move toward the results for our entire table.
# This could be considered roughly similar to our lesson on a standard distribution. As we continue to add values, the bell curve distribution becomes more and more evident.

# %% [markdown]
# ### Step 4 - Add new field: Max order

# %%
# Create new column, assign max order quantity for each user
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138    prior            28          6                 11
# 1   1977647      138    prior            30          6                 17
# 2    389851      709    prior             2          0                 21
# 3    652770      764    prior             1          3                 13
# 4   1813452      764    prior             3          4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# 0                     3.0                  5          0   both
# 1                    20.0                  1          1   both
# 2                     6.0                 20          0   both
# 3                     0.0                 10          0   both
# 4                     9.0                 11          1   both
#
#      price_range_loc     busiest_day       busiest_days_2  \
# 0  Mid-range product  Regularly busy  Regularly busy days
# 1  Mid-range product  Regularly busy  Regularly busy days
# 2  Mid-range product     Busiest day         Busiest days
# 3  Mid-range product  Regularly busy      Least busy days
# 4  Mid-range product      Least busy      Least busy days
#
#           busiest_hours  max_order
# 0         Busiest hours         32
# 1  Regularly busy hours         32
# 2  Regularly busy hours          5
# 3  Regularly busy hours          3
# 4  Regularly busy hours          3

# %% [markdown]
# ### Step 5 - Create loyalty flag per max_order data

# %%
# Create loyalty flag
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  ...  \
# 0   3139998      138    prior            28          6  ...
# 1   1977647      138    prior            30          6  ...
# 2    389851      709    prior             2          0  ...
# 3    652770      764    prior             1          3  ...
# 4   1813452      764    prior             3          4  ...
#
#    days_since_prior_order  add_to_cart_order  reordered  _merge  \
# 0                     3.0                  5          0    both
# 1                    20.0                  1          1    both
# 2                     6.0                 20          0    both
# 3                     0.0                 10          0    both
# 4                     9.0                 11          1    both
#
#      price_range_loc     busiest_day       busiest_days_2  \
# 0  Mid-range product  Regularly busy  Regularly busy days
# 1  Mid-range product  Regularly busy  Regularly busy days
# 2  Mid-range product     Busiest day         Busiest days
# 3  Mid-range product  Regularly busy      Least busy days
# 4  Mid-range product      Least busy      Least busy days
#
#           busiest_hours max_order      loyalty_flag
# 0         Busiest hours        32  Regular customer
# 1  Regularly busy hours        32  Regular customer
# 2  Regularly busy hours         5      New customer
# 3  Regularly busy hours         3      New customer
# 4  Regularly busy hours         3      New customer
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Confirm loyalty_flag applied correctly

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# 20     1540  Regular customer             7
# 21     1540  Regular customer             8
# 22     1540  Regular customer             9
# 23     1540  Regular customer            14
# 24     1540  Regular customer            15
# 25     1540  Regular customer            18
# 26     1540  Regular customer            19
# 27     1540  Regular customer            20
# 28     1540  Regular customer            21
# 29     1540  Regular customer            22
# 30     1540  Regular customer            24
# 31     1540  Regular customer            25
# 32     1540  Regular customer            27
# 33     1540  Regular customer            28
# 34     1598      New customer             1
# 35     1598      New customer             2
# 36     1598      New customer             3
# 37     1647      New customer             1
# 38     1647      New customer             4
# 39     1647      New customer             6
# 40     1647      New customer             8
# 41     1647      New customer             9
# 42     2833      New customer             1
# 43     2850  Regular customer             7
# 44     2857  Regular customer            24
# 45     3010  Regular customer             5
# 46     3029      New customer             1
# 47     3395      New customer             4
# 48     3904      New customer             1
# 49     4006    Loyal customer             2
# 50     4006    Loyal customer             3
# 51     4006    Loyal customer             5
# 52     4006    Loyal customer             9
# 53     4006    Loyal customer            12
# 54     4122  Regular customer            11
# 55     4141      New customer             2
# 56     4343      New customer             1
# 57     4553      New customer             3
# 58     4845  Regular customer             6
# 59     6866      New customer             1

# %% [markdown]
# ### Step 6 - Add new field: Average price of items purchased as avg_spend

# %%
# Create new column, assign mean spend value for each user
df_ords_prods_merge['avg_spend'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  ...  \
# 0   3139998      138    prior            28          6  ...
# 1   1977647      138    prior            30          6  ...
# 2    389851      709    prior             2          0  ...
# 3    652770      764    prior             1          3  ...
# 4   1813452      764    prior             3          4  ...
#
#    add_to_cart_order  reordered  _merge    price_range_loc     busiest_day  \
# 0                  5          0    both  Mid-range product  Regularly busy
# 1                  1          1    both  Mid-range product  Regularly busy
# 2                 20          0    both  Mid-range product     Busiest day
# 3                 10          0    both  Mid-range product  Regularly busy
# 4                 11          1    both  Mid-range product      Least busy
#
#         busiest_days_2         busiest_hours max_order      loyalty_flag  \
# 0  Regularly busy days         Busiest hours        32  Regular customer
# 1  Regularly busy days  Regularly busy hours        32  Regular customer
# 2         Busiest days  Regularly busy hours         5      New customer
# 3      Least busy days  Regularly busy hours         3      New customer
# 4      Least busy days  Regularly busy hours         3      New customer
#
#    avg_spend
# 0   6.935811
# 1   6.935811
# 2   7.930208
# 3   4.972414
# 4   4.972414
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Create spending_flag per avg_spend data

# %%
# Create spending flag and assign a designation
df_ords_prods_merge.loc[df_ords_prods_merge['avg_spend'] >= 10, 'spending_flag'] = 'High spender'
df_ords_prods_merge.loc[df_ords_prods_merge['avg_spend'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Change settings to remove limit on rows displayed
pd.options.display.max_rows = None

# %%
df_ords_prods_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
# 15           1  Chocolate Sandwich Cookies        61             19     5.8
# 16           1  Chocolate Sandwich Cookies        61             19     5.8
# 17           1  Chocolate Sandwich Cookies        61             19     5.8
# 18           1  Chocolate Sandwich Cookies        61             19     5.8
# 19           1  Chocolate Sandwich Cookies        61             19     5.8
# 81           1  Chocolate Sandwich Cookies        61             19     5.8
# 82           1  Chocolate Sandwich Cookies        61             19     5.8
# 83           1  Chocolate Sandwich Cookies        61             19     5.8
# 84           1  Chocolate Sandwich Cookies        61             19     5.8
# 85           1  Chocolate Sandwich Cookies        61             19     5.8
# 86           1  Chocolate Sandwich Cookies        61             19     5.8
# 87           1  Chocolate Sandwich Cookies        61             19     5.8
# 88           1  Chocolate Sandwich Cookies        61             19     5.8
# 89           1  Chocolate Sandwich Cookies        61             19     5.8
# 90           1  Chocolate Sandwich Cookies        61             19     5.8
# 91           1  Chocolate Sandwich Cookies        61             19     5.8
# 92           1  Chocolate Sandwich Cookies        61             19     5.8
# 93           1  Chocolate Sandwich Cookies        61             19     5.8
# 94           1  Chocolate Sandwich Cookies        61             19     5.8
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id eval_set  order_number  order_dow  ...  reordered  \
# 0    3139998      138    prior            28          6  ...          0
# 1    1977647      138    prior            30          6  ...          1
# 2     389851      709    prior             2          0  ...          0
# 3     652770      764    prior             1          3  ...          0
# 4    1813452      764    prior             3          4  ...          1
# 5    1701441      777    prior            16          1  ...          0
# 6    1871483      825    prior             3          2  ...          0
# 7    1290456      910    prior            12          3  ...          0
# 8     369558     1052    prior            10          1  ...          0
# 9     589712     1052    prior            15          1  ...          1
# 10   1798115     1379    prior             1          5  ...          0
# 11    497193     1480    prior            36          3  ...          0
# 12   1727826     1480    prior            38          4  ...          1
# 13   2694698     1480    prior            39          2  ...          1
# 14   3171753     1494    prior             6          3  ...          0
# 15    186761     1494    prior             7          2  ...          1
# 16    317121     1494    prior             9          5  ...          1
# 17    200390     1540    prior             4          2  ...          0
# 18    374436     1540    prior             5          1  ...          1
# 19   2920553     1540    prior             6          1  ...          1
# 20   2813049     1540    prior             7          2  ...          1
# 21   2365998     1540    prior             8          1  ...          1
# 22   1604797     1540    prior             9          1  ...          1
# 23   2799665     1540    prior            14          1  ...          1
# 24   2228851     1540    prior            15          1  ...          1
# 25   2337422     1540    prior            18          0  ...          1
# 26   2699008     1540    prior            19          0  ...          1
# 27   1914830     1540    prior            20          0  ...          1
# 28    783503     1540    prior            21          0  ...          1
# 29   2500516     1540    prior            22          0  ...          1
# 30    716845     1540    prior            24          4  ...          1
# 31   1955535     1540    prior            25          6  ...          1
# 32   1424793     1540    prior            27          1  ...          1
# 33    749498     1540    prior            28          0  ...          1
# 34   2434812     1598    prior             1          2  ...          0
# 35   1531889     1598    prior             2          2  ...          1
# 36    726947     1598    prior             3          4  ...          1
# 37    627615     1647    prior             1          1  ...          0
# 38   2507439     1647    prior             4          0  ...          1
# 39   1152609     1647    prior             6          1  ...          1
# 40   1048339     1647    prior             8          0  ...          1
# 41   2818381     1647    prior             9          4  ...          1
# 42   2722928     2833    prior             1          0  ...          0
# 43   1482338     2850    prior             7          1  ...          0
# 44   2311344     2857    prior            24          1  ...          0
# 45    812943     3010    prior             5          3  ...          0
# 46    256839     3029    prior             1          2  ...          0
# 47   2192488     3395    prior             4          2  ...          0
# 48    207661     3904    prior             1          1  ...          0
# 49   1394659     4006    prior             2          1  ...          0
# 50   2353526     4006    prior             3          1  ...          1
# 51   2269226     4006    prior             5          3  ...          1
# 52    367316     4006    prior             9          2  ...          1
# 53   1448367     4006    prior            12          1  ...          1
# 54     19989     4122    prior            11          2  ...          0
# 55   2735922     4141    prior             2          0  ...          0
# 56   2469422     4343    prior             1          1  ...          0
# 57   3185558     4553    prior             3          5  ...          0
# 58    350540     4845    prior             6          0  ...          0
# 59    513100     6866    prior             1          4  ...          0
# 60   2081405     7275    prior             5          2  ...          0
# 61   2209807     7669    prior             3          3  ...          0
# 62    921798     7669    prior             4          1  ...          1
# 63   2540226     7669    prior            20          1  ...          1
# 64   2265792     7981    prior             9          2  ...          0
# 65   3357714     7981    prior            13          0  ...          1
# 66   1186573     7981    prior            14          2  ...          1
# 67   3209740     7981    prior            24          2  ...          1
# 68    138748     7981    prior            30          3  ...          1
# 69   2027157     8703    prior            34          4  ...          0
# 70   3052954     8723    prior             4          3  ...          0
# 71   1486756     8735    prior             8          4  ...          0
# 72    632514     9293    prior             2          0  ...          0
# 73   1253470     9293    prior             3          3  ...          1
# 74    837303     9467    prior             1          0  ...          0
# 75   2734881     9694    prior             2          0  ...          0
# 76   2164394     9694    prior             4          4  ...          1
# 77   3354551     9694    prior             5          4  ...          1
# 78   1381165     9694    prior             6          4  ...          1
# 79   2809438     9694    prior             7          4  ...          1
# 80    425352     9694    prior            10          4  ...          1
# 81   2453441     9694    prior            14          4  ...          1
# 82   1189695     9694    prior            15          4  ...          1
# 83   1759231     9694    prior            16          4  ...          1
# 84    482648     9694    prior            20          4  ...          1
# 85   2201348     9694    prior            22          4  ...          1
# 86   3351592     9848    prior            17          4  ...          0
# 87   2164672    10113    prior             6          4  ...          0
# 88   1526735    10315    prior             1          0  ...          0
# 89   2057892    10479    prior            22          1  ...          0
# 90    356685    10708    prior             4          2  ...          0
# 91   1592736    10708    prior             8          2  ...          1
# 92   3125810    10789    prior            10          0  ...          0
# 93    846661    10789    prior            11          0  ...          1
# 94   2363761    10789    prior            16          2  ...          1
# 95    602103    10831    prior             8          3  ...          0
# 96     49629    11119    prior            18          1  ...          0
# 97    317888    11186    prior            13          5  ...          0
# 98    682486    11243    prior            16          3  ...          0
# 99   2861386    11448    prior            10          2  ...          0
#
#     _merge    price_range_loc     busiest_day       busiest_days_2  \
# 0     both  Mid-range product  Regularly busy  Regularly busy days
# 1     both  Mid-range product  Regularly busy  Regularly busy days
# 2     both  Mid-range product     Busiest day         Busiest days
# 3     both  Mid-range product  Regularly busy      Least busy days
# 4     both  Mid-range product      Least busy      Least busy days
# 5     both  Mid-range product  Regularly busy         Busiest days
# 6     both  Mid-range product  Regularly busy  Regularly busy days
# 7     both  Mid-range product  Regularly busy      Least busy days
# 8     both  Mid-range product  Regularly busy         Busiest days
# 9     both  Mid-range product  Regularly busy         Busiest days
# 10    both  Mid-range product  Regularly busy  Regularly busy days
# 11    both  Mid-range product  Regularly busy      Least busy days
# 12    both  Mid-range product      Least busy      Least busy days
# 74    both  Mid-range product     Busiest day         Busiest days
# 75    both  Mid-range product     Busiest day         Busiest days
# 76    both  Mid-range product      Least busy      Least busy days
# 77    both  Mid-range product      Least busy      Least busy days
# 78    both  Mid-range product      Least busy      Least busy days
# 79    both  Mid-range product      Least busy      Least busy days
# 80    both  Mid-range product      Least busy      Least busy days
# 81    both  Mid-range product      Least busy      Least busy days
# 82    both  Mid-range product      Least busy      Least busy days
# 83    both  Mid-range product      Least busy      Least busy days
# 84    both  Mid-range product      Least busy      Least busy days
# 85    both  Mid-range product      Least busy      Least busy days
# 86    both  Mid-range product      Least busy      Least busy days
# 87    both  Mid-range product      Least busy      Least busy days
# 88    both  Mid-range product     Busiest day         Busiest days
# 89    both  Mid-range product  Regularly busy         Busiest days
# 90    both  Mid-range product  Regularly busy  Regularly busy days
# 91    both  Mid-range product  Regularly busy  Regularly busy days
# 92    both  Mid-range product     Busiest day         Busiest days
# 93    both  Mid-range product     Busiest day         Busiest days
# 94    both  Mid-range product  Regularly busy  Regularly busy days
# 95    both  Mid-range product  Regularly busy      Least busy days
# 96    both  Mid-range product  Regularly busy         Busiest days
# 97    both  Mid-range product  Regularly busy  Regularly busy days
# 98    both  Mid-range product  Regularly busy      Least busy days
# 99    both  Mid-range product  Regularly busy  Regularly busy days
#
#            busiest_hours max_order      loyalty_flag  avg_spend  spending_flag
# 0          Busiest hours        32  Regular customer   6.935811    Low spender
# 1   Regularly busy hours        32  Regular customer   6.935811    Low spender
# 2   Regularly busy hours         5      New customer   7.930208    Low spender
# 3   Regularly busy hours         3      New customer   4.972414    Low spender
# 4   Regularly busy hours         3      New customer   4.972414    Low spender
# 5   Regularly busy hours        26  Regular customer   6.935398    Low spender
# 6          Busiest hours         9      New customer   5.957576    Low spender
# 7          Busiest hours        12  Regular customer   6.680000    Low spender
# 8   Regularly busy hours        20  Regular customer   7.162500    Low spender
# 9   Regularly busy hours        20  Regular customer   7.162500    Low spender
# 10         Busiest hours        10      New customer   5.813636    Low spender
# 11  Regularly busy hours        43    Loyal customer   5.081633    Low spender
# 12  Regularly busy hours        43    Loyal customer   5.081633    Low spender
# 13  Regularly busy hours        43    Loyal customer   5.081633    Low spender
# 14         Busiest hours        13  Regular customer   6.803797    Low spender
# 15  Regularly busy hours        13  Regular customer   6.803797    Low spender
# 16  Regularly busy hours        13  Regular customer   6.803797    Low spender
# 17  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 18  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 19  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 20      Least busy hours        28  Regular customer   6.607122    Low spender
# 21  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 22      Least busy hours        28  Regular customer   6.607122    Low spender
# 23         Busiest hours        28  Regular customer   6.607122    Low spender
# 24         Busiest hours        28  Regular customer   6.607122    Low spender
# 25  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 26  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 27  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 28  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 29  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 30  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 31  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 32  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 33  Regularly busy hours        28  Regular customer   6.607122    Low spender
# 34  Regularly busy hours         4      New customer   7.123529    Low spender
# 35         Busiest hours         4      New customer   7.123529    Low spender
# 36  Regularly busy hours         4      New customer   7.123529    Low spender
# 37  Regularly busy hours        10      New customer   4.853521    Low spender
# 38  Regularly busy hours        10      New customer   4.853521    Low spender
# 39  Regularly busy hours        10      New customer   4.853521    Low spender
# 40  Regularly busy hours        10      New customer   4.853521    Low spender
# 41         Busiest hours        10      New customer   4.853521    Low spender
# 42         Busiest hours        10      New customer   7.377143    Low spender
# 43  Regularly busy hours        23  Regular customer   8.054153    Low spender
# 44  Regularly busy hours        25  Regular customer   8.353793    Low spender
# 45         Busiest hours        13  Regular customer   6.452800    Low spender
# 46  Regularly busy hours         5      New customer   7.960606    Low spender
# 47         Busiest hours         6      New customer   6.322222    Low spender
# 48         Busiest hours         3      New customer   7.511111    Low spender
# 49         Busiest hours        42    Loyal customer   7.441100    Low spender
# 50         Busiest hours        42    Loyal customer   7.441100    Low spender
# 51  Regularly busy hours        42    Loyal customer   7.441100    Low spender
# 52         Busiest hours        42    Loyal customer   7.441100    Low spender
# 53         Busiest hours        42    Loyal customer   7.441100    Low spender
# 54  Regularly busy hours        40  Regular customer   7.598765    Low spender
# 55  Regularly busy hours         9      New customer   6.033333    Low spender
# 56  Regularly busy hours         4      New customer   7.393939    Low spender
# 57  Regularly busy hours         4      New customer   5.715789    Low spender
# 58  Regularly busy hours        14  Regular customer   7.229630    Low spender
# 59         Busiest hours         6      New customer   4.807143    Low spender
# 60  Regularly busy hours         8      New customer   4.620833    Low spender
# 61         Busiest hours        21  Regular customer   9.106757    Low spender
# 62  Regularly busy hours        21  Regular customer   9.106757    Low spender
# 63  Regularly busy hours        21  Regular customer   9.106757    Low spender
# 64         Busiest hours        31  Regular customer   7.115714    Low spender
# 65  Regularly busy hours        31  Regular customer   7.115714    Low spender
# 66  Regularly busy hours        31  Regular customer   7.115714    Low spender
# 67  Regularly busy hours        31  Regular customer   7.115714    Low spender
# 68  Regularly busy hours        31  Regular customer   7.115714    Low spender
# 69  Regularly busy hours        99    Loyal customer   6.593459    Low spender
# 70         Busiest hours        36  Regular customer   5.677397    Low spender
# 71         Busiest hours         9      New customer   5.850000    Low spender
# 72  Regularly busy hours         5      New customer  11.857143   High spender
# 73  Regularly busy hours         5      New customer  11.857143   High spender
# 74  Regularly busy hours         5      New customer   7.709091    Low spender
# 75  Regularly busy hours        23  Regular customer   7.075354    Low spender
# 76  Regularly busy hours        23  Regular customer   7.075354    Low spender
# 77         Busiest hours        23  Regular customer   7.075354    Low spender
# 78  Regularly busy hours        23  Regular customer   7.075354    Low spender
# 79  Regularly busy hours        23  Regular customer   7.075354    Low spender
# 80  Regularly busy hours        23  Regular customer   7.075354    Low spender
# 81  Regularly busy hours        23  Regular customer   7.075354    Low spender
# 82  Regularly busy hours        23  Regular customer   7.075354    Low spender
# 83         Busiest hours        23  Regular customer   7.075354    Low spender
# 84  Regularly busy hours        23  Regular customer   7.075354    Low spender
# 85         Busiest hours        23  Regular customer   7.075354    Low spender
# 86  Regularly busy hours        23  Regular customer   8.312203    Low spender
# 87  Regularly busy hours        11  Regular customer   8.769565    Low spender
# 88  Regularly busy hours         5      New customer  10.188889   High spender
# 89  Regularly busy hours        22  Regular customer   7.779775    Low spender
# 90         Busiest hours        21  Regular customer   7.777403    Low spender
# 91         Busiest hours        21  Regular customer   7.777403    Low spender
# 92  Regularly busy hours        36  Regular customer   6.097701    Low spender
# 93  Regularly busy hours        36  Regular customer   6.097701    Low spender
# 94  Regularly busy hours        36  Regular customer   6.097701    Low spender
# 95         Busiest hours        10      New customer   7.494286    Low spender
# 96         Busiest hours        23  Regular customer   5.878641    Low spender
# 97  Regularly busy hours        26  Regular customer   6.618085    Low spender
# 98  Regularly busy hours        43    Loyal customer   5.927149    Low spender
# 99         Busiest hours        21  Regular customer   5.981250    Low spender
#
# [100 rows x 23 columns]

# %% [markdown]
# ### Step 7 - Add new field: Median frequency of customers as frequency_median

# %%
# Create new column, assign median frequency value for each user
df_ords_prods_merge['frequency_median'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Confirm write of field
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  ...  _merge  \
# 0   3139998      138    prior            28          6  ...    both
# 1   1977647      138    prior            30          6  ...    both
# 2    389851      709    prior             2          0  ...    both
# 3    652770      764    prior             1          3  ...    both
# 4   1813452      764    prior             3          4  ...    both
#
#      price_range_loc     busiest_day       busiest_days_2  \
# 0  Mid-range product  Regularly busy  Regularly busy days
# 1  Mid-range product  Regularly busy  Regularly busy days
# 2  Mid-range product     Busiest day         Busiest days
# 3  Mid-range product  Regularly busy      Least busy days
# 4  Mid-range product      Least busy      Least busy days
#
#           busiest_hours max_order      loyalty_flag avg_spend spending_flag  \
# 0         Busiest hours        32  Regular customer  6.935811   Low spender
# 1  Regularly busy hours        32  Regular customer  6.935811   Low spender
# 2  Regularly busy hours         5      New customer  7.930208   Low spender
# 3  Regularly busy hours         3      New customer  4.972414   Low spender
# 4  Regularly busy hours         3      New customer  4.972414   Low spender
#
#    frequency_median
# 0               8.0
# 1               8.0
# 2               6.0
# 3               9.0
# 4               9.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Create a frequency flag per the frequency_median

# %%
# Create frequency flag
df_ords_prods_merge.loc[df_ords_prods_merge['frequency_median'] > 20, 'frequency_flag'] = 'Non-frequent customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['frequency_median'] <= 20) & (df_ords_prods_merge['frequency_median'] > 10), 'frequency_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['frequency_median'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  ...  \
# 0   3139998      138    prior            28          6  ...
# 1   1977647      138    prior            30          6  ...
# 2    389851      709    prior             2          0  ...
# 3    652770      764    prior             1          3  ...
# 4   1813452      764    prior             3          4  ...
#
#      price_range_loc     busiest_day       busiest_days_2  \
# 0  Mid-range product  Regularly busy  Regularly busy days
# 1  Mid-range product  Regularly busy  Regularly busy days
# 2  Mid-range product     Busiest day         Busiest days
# 3  Mid-range product  Regularly busy      Least busy days
# 4  Mid-range product      Least busy      Least busy days
#
#           busiest_hours max_order      loyalty_flag avg_spend spending_flag  \
# 0         Busiest hours        32  Regular customer  6.935811   Low spender
# 1  Regularly busy hours        32  Regular customer  6.935811   Low spender
# 2  Regularly busy hours         5      New customer  7.930208   Low spender
# 3  Regularly busy hours         3      New customer  4.972414   Low spender
# 4  Regularly busy hours         3      New customer  4.972414   Low spender
#
#   frequency_median     frequency_flag
# 0              8.0  Frequent customer
# 1              8.0  Frequent customer
# 2              6.0  Frequent customer
# 3              9.0  Frequent customer
# 4              9.0  Frequent customer
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Export final data

# %%
# Export df_ords_prods_merge as orders_products_w_customer_flags.pkl
df_ords_prods_merge.to_pickle(os.path.join(path, 'Prepared Data', 'orders_products_w_customer_flags.pkl'))

# %%
# Import orders_products_w_customer_flags.pkl for good write confirmation
df_temp = pd.read_pickle(os.path.join(path, 'Prepared Data', 'orders_products_w_customer_flags.pkl'))

# %%
df_temp.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  ...  \
# 0   3139998      138    prior            28          6  ...
# 1   1977647      138    prior            30          6  ...
# 2    389851      709    prior             2          0  ...
# 3    652770      764    prior             1          3  ...
# 4   1813452      764    prior             3          4  ...
#
#      price_range_loc     busiest_day       busiest_days_2  \
# 0  Mid-range product  Regularly busy  Regularly busy days
# 1  Mid-range product  Regularly busy  Regularly busy days
# 2  Mid-range product     Busiest day         Busiest days
# 3  Mid-range product  Regularly busy      Least busy days
# 4  Mid-range product      Least busy      Least busy days
#
#           busiest_hours max_order      loyalty_flag avg_spend spending_flag  \
# 0         Busiest hours        32  Regular customer  6.935811   Low spender
# 1  Regularly busy hours        32  Regular customer  6.935811   Low spender
# 2  Regularly busy hours         5      New customer  7.930208   Low spender
# 3  Regularly busy hours         3      New customer  4.972414   Low spender
# 4  Regularly busy hours         3      New customer  4.972414   Low spender
#
#   frequency_median     frequency_flag
# 0              8.0  Frequent customer
# 1              8.0  Frequent customer
# 2              6.0  Frequent customer
# 3              9.0  Frequent customer
# 4              9.0  Frequent customer
#
# [5 rows x 25 columns]
